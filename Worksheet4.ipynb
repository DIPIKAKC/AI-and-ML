# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile
zip_ref = zipfile.ZipFile('/content/drive/MyDrive/Artificial Intelligence and Machine Learning/Week4/Copy of devnagari digit.zip', 'r')
zip_ref.extractall('/content')
zip_ref.close()

# %%
# data.data.districts
import tensorflow as tf
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, BatchNormalization, Dropout

# %%
# generators -> divide all the data to batches
# each time batch is loaded on RAM and remove after job done and
# process continues until all batches done
train_ds = keras.utils.image_dataset_from_directory(
    directory = '/content/DevanagariHandwrittenDigitDataset/Train',
    labels = 'inferred',
    label_mode = 'int',
    batch_size = 128,
    image_size = (256, 256)
)

validation_ds = keras.utils.image_dataset_from_directory(
    directory = '/content/DevanagariHandwrittenDigitDataset/Test',
    labels = 'inferred',
    label_mode = 'int',
    batch_size = 128,
    image_size = (256, 256)
)
# Out:
# Found 17000 files belonging to 10 classes.
# Found 3000 files belonging to 10 classes.

# %%
#normalize -> for value (0 to 255) to (0 to 1)
def process(image,label):
  image = tf.cast(image/255. ,tf.float32)
  return image,label


train_ds = train_ds.map(process)
validation_ds = validation_ds.map(process)

# %%
#prediction
import cv2

test_image1_0 = cv2.imread('/content/DevanagariHandwrittenDigitDataset/Train/digit_0/103265.png')
test_image2_9 = cv2.imread('/content/DevanagariHandwrittenDigitDataset/Test/digit_9/10407.png')
test_image2_2 = cv2.imread('/content/DevanagariHandwrittenDigitDataset/Test/digit_2/12535.png')

# %%
import matplotlib.pyplot as plt
plt.imshow(test_image1_0)

# %%
plt.imshow(test_image2_9)

# %%
plt.imshow(test_image2_2)

# %%
test_image2_9.shape
# Out:
# (32, 32, 3)

# %%
#decreasing image size
test_image1 = cv2.resize(test_image2_9,(256,256)) # Resized to (256, 256)
test_image2 = cv2.resize(test_image1_0,(256,256)) # Resized to (256, 256)
test_image3 = cv2.resize(test_image2_2,(256,256)) # Resized to (256, 256)

# %%
#reshaping image shape
test_input1 = test_image1.reshape((1,256,256,3)) # Reshaped to (1, 256, 256, 3)
test_input2 = test_image2.reshape((1,256,256,3)) # Reshaped to (1, 256, 256, 3)
test_input3 = test_image3.reshape((1,256,256,3)) # Reshaped to (1, 256, 256, 3)

# %%
#using ANN
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten

# %%
# Normalize the pixel values to range [0,1]
normalization_layer = keras.layers.Rescaling(1./255)
train_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
validation_ds = validation_ds.map(lambda x, y: (normalization_layer(x), y))

# %%
ann_model = Sequential()
ann_model.add(Flatten(input_shape=(256, 256, 3)))
ann_model.add(Dense(64, activation='sigmoid'))
ann_model.add(Dropout(0.3))
ann_model.add(Dense(128, activation='sigmoid'))
ann_model.add(Dropout(0.2))
ann_model.add(Dense(256, activation='sigmoid'))
ann_model.add(Dropout(0.1))
ann_model.add(Dense(10, activation='softmax'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Compile the model
ann_model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    metrics=['accuracy']
)

# %%
# Summary of the model
ann_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)                    │ (None, 196608)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │      12,582,976 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 128)                 │           8,320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 256)                 │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 10)                  │           2,570 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 12,626,890 (48.17 MB)
#  Trainable params: 12,626,890 (48.17 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model using the data generators
history = ann_model.fit(
    train_ds,
    validation_data=validation_ds,
    epochs=20
)
# Out:
# Epoch 1/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 103s 743ms/step - accuracy: 0.1650 - loss: 2.2591 - val_accuracy: 0.7270 - val_loss: 1.1224
# Epoch 2/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 86s 645ms/step - accuracy: 0.7183 - loss: 0.9574 - val_accuracy: 0.8513 - val_loss: 0.4759
# Epoch 3/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 144s 662ms/step - accuracy: 0.8280 - loss: 0.5163 - val_accuracy: 0.8983 - val_loss: 0.3400
# Epoch 4/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 88s 663ms/step - accuracy: 0.8596 - loss: 0.4029 - val_accuracy: 0.9107 - val_loss: 0.2745
# Epoch 5/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 94s 705ms/step - accuracy: 0.8906 - loss: 0.3334 - val_accuracy: 0.9323 - val_loss: 0.2229
# Epoch 6/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 88s 659ms/step - accuracy: 0.9091 - loss: 0.2886 - val_accuracy: 0.9450 - val_loss: 0.1903
# Epoch 7/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 95s 709ms/step - accuracy: 0.9170 - loss: 0.2518 - val_accuracy: 0.9527 - val_loss: 0.1700
# Epoch 8/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 88s 651ms/step - accuracy: 0.9292 - loss: 0.2150 - val_accuracy: 0.9587 - val_loss: 0.1494
# Epoch 9/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 92s 684ms/step - accuracy: 0.9311 - loss: 0.2092 - val_accuracy: 0.9597 - val_loss: 0.1400
# Epoch 10/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 87s 655ms/step - accuracy: 0.9402 - loss: 0.1850 - val_accuracy: 0.9630 - val_loss: 0.1267
# Epoch 11/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 90s 675ms/step - accuracy: 0.9434 - loss: 0.1746 - val_accuracy: 0.9627 - val_loss: 0.1221
# Epoch 12/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 140s 661ms/step - accuracy: 0.9455 - loss: 0.1667 - val_accuracy: 0.9650 - val_loss: 0.1147
# Epoch 13/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 146s 694ms/step - accuracy: 0.9511 - loss: 0.1517 - val_accuracy: 0.9680 - val_loss: 0.1066
# Epoch 14/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 91s 680ms/step - accuracy: 0.9522 - loss: 0.1442 - val_accuracy: 0.9677 - val_loss: 0.1024
# Epoch 15/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 88s 657ms/step - accuracy: 0.9554 - loss: 0.1298 - val_accuracy: 0.9707 - val_loss: 0.0993
# Epoch 16/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 88s 659ms/step - accuracy: 0.9605 - loss: 0.1220 - val_accuracy: 0.9680 - val_loss: 0.0997
# Epoch 17/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 87s 655ms/step - accuracy: 0.9595 - loss: 0.1177 - val_accuracy: 0.9707 - val_loss: 0.0979
# Epoch 18/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 91s 683ms/step - accuracy: 0.9630 - loss: 0.1164 - val_accuracy: 0.9723 - val_loss: 0.0910
# Epoch 19/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 88s 659ms/step - accuracy: 0.9641 - loss: 0.1101 - val_accuracy: 0.9737 - val_loss: 0.0905
# Epoch 20/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 88s 663ms/step - accuracy: 0.9646 - loss: 0.1021 - val_accuracy: 0.9730 - val_loss: 0.0865

# %%
#accuracy graph
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], color='red', label='train')
plt.plot(history.history['val_accuracy'], color='blue', label='validation')
plt.legend()
plt.show()

# %%
#losss graph
import matplotlib.pyplot as plt

plt.plot(history.history['loss'], color='red', label='train')
plt.plot(history.history['val_loss'], color='blue', label='validation')
plt.legend()
plt.show()

# %%
test_input3.shape
# Out:
# (1, 256, 256, 3)

# %%
import numpy as np
pred = ann_model.predict(test_input3) #2
pred_digit = np.argmax(pred)
print(f"predicted output image value is {pred_digit}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# predicted output image value is 2

# %%
import numpy as np
# Predict on test data
predictions = ann_model.predict(validation_ds)
# Convert predictions from probabilities to digit labels
predicted_labels = np.argmax(predictions, axis=1)
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 327ms/step

# %%
print("Prediction : ",predictions[0])
print("Predicted label : ",predicted_labels[0])
print("Prdection shape", predictions[0].shape)
# Out:
# Prediction :  [3.0161807e-04 3.2994332e-05 2.8565191e-05 1.2502739e-08 1.6049980e-04
#  2.6471545e-07 1.1941524e-06 4.3020510e-08 9.9929547e-01 1.7938134e-04]
# Predicted label :  8
# Prdection shape (10,)

# %%
# Check the first prediction
print(f"Predicted label for first image: {predicted_labels[0]}")
# Out:
# Predicted label for first image: 8

# %%
# Get the shape of the first image in the validation dataset
for image, label in validation_ds.take(2):
  print("Image shape:", image.shape)
  print("Label shape:", label.shape)
# Out:
# Image shape: (128, 256, 256, 3)
# Label shape: (128,)
# Image shape: (128, 256, 256, 3)
# Label shape: (128,)

# %%
ann_model.save("ann_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
loaded_model = tf.keras.models.load_model("ann_model.h5")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
predict1 = loaded_model.predict(test_input3) #image is 2
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step

# %%
predicted_digit = np.argmax(predict1)
print("Predicted digit:", predicted_digit)
# Out:
# Predicted digit: 2
